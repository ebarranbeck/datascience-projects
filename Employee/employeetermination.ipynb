# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, StandardScaler

from sklearn.linear_model import LogisticRegression

# %%
data=pd.read_csv('MFG10YearTerminationData.csv')

# %%
data.head()
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# 1       CEO          35            M        Male  Not Applicable
# 2       CEO          35            M        Male  Not Applicable
# 3       CEO          35            M        Male  Not Applicable
# 4       CEO          35            M        Male  Not Applicable
#
#     termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# 0  Not Applicable         2006  ACTIVE    HEADOFFICE
# 1  Not Applicable         2007  ACTIVE    HEADOFFICE
# 2  Not Applicable         2008  ACTIVE    HEADOFFICE
# 3  Not Applicable         2009  ACTIVE    HEADOFFICE
# 4  Not Applicable         2010  ACTIVE    HEADOFFICE

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49653 entries, 0 to 49652
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EmployeeID           49653 non-null  int64
#  1   recorddate_key       49653 non-null  object
#  2   birthdate_key        49653 non-null  object
#  3   orighiredate_key     49653 non-null  object
#  4   terminationdate_key  49653 non-null  object
#  5   age                  49653 non-null  int64
#  6   length_of_service    49653 non-null  int64
#  7   city_name            49653 non-null  object
#  8   department_name      49653 non-null  object
#  9   job_title            49653 non-null  object
#  10  store_name           49653 non-null  int64
#  11  gender_short         49653 non-null  object
#  12  gender_full          49653 non-null  object
#  13  termreason_desc      49653 non-null  object
#  14  termtype_desc        49653 non-null  object
#  15  STATUS_YEAR          49653 non-null  int64
#  16  STATUS               49653 non-null  object
#  17  BUSINESS_UNIT        49653 non-null  object
# dtypes: int64(5), object(13)
# memory usage: 6.8+ MB

# %% [markdown]
# # Initial Preprocessing

# %%
def preprocess_inputs(df):
    df=df.copy()
    # drop unnessecary columns
    df=df.drop(['EmployeeID','gender_short'],axis=1)
    
    #drop columns not available before termination
    df=df.drop(['terminationdate_key','length_of_service','termreason_desc','termtype_desc'],axis=1)
    X=df.drop(['STATUS'],axis=1)
    y=df['STATUS']
    
    #train-test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test=preprocess_inputs(data)

# %%
X_train
# Out:
#         recorddate_key birthdate_key orighiredate_key  age        city_name  \
# 36271  12/31/2011 0:00     8/18/1979       10/30/2005   32       Abbotsford
# 3950   12/31/2008 0:00     4/27/1953        12/8/1991   55        Vancouver
# 26963  12/31/2006 0:00     9/26/1971        8/29/2001   35  New Westminster
# 29451  12/31/2011 0:00    10/16/1973        9/30/2002   38          Terrace
# 3790   12/31/2008 0:00     3/10/1953       11/13/1991   55          Burnaby
# ...                ...           ...              ...  ...              ...
# 11284  12/31/2010 0:00      6/9/1959         3/2/1995   51        Vancouver
# 44732  12/31/2013 0:00     4/26/1988         6/1/2010   25          Terrace
# 38158  12/31/2012 0:00     3/13/1981        8/28/2006   31          Nanaimo
# 860    12/31/2007 0:00      2/6/1950        3/27/1990   57         Kamloops
# 15795  12/31/2011 0:00    12/14/1962         1/8/1997   49          Langley
#
#         department_name                job_title  store_name gender_full  \
# 36271            Bakery                    Baker           1        Male
# 3950            Produce            Produce Clerk          41      Female
# 26963            Bakery                    Baker          21        Male
# 29451   Processed Foods            Shelf Stocker          32        Male
# 3790              Meats              Meat Cutter           5        Male
# ...                 ...                      ...         ...         ...
# 11284             Meats              Meat Cutter          42        Male
# 44732  Customer Service                  Cashier          32      Female
# 38158   Processed Foods            Shelf Stocker          18      Female
# 860     Processed Foods  Processed Foods Manager          15        Male
# 15795           Produce            Produce Clerk          17      Female
#
#        STATUS_YEAR BUSINESS_UNIT
# 36271         2011        STORES
# 3950          2008        STORES
# 26963         2006        STORES
# 29451         2011        STORES
# 3790          2008        STORES
# ...            ...           ...
# 11284         2010        STORES
# 44732         2013        STORES
# 38158         2012        STORES
# 860           2007        STORES
# 15795         2011        STORES
#
# [34757 rows x 11 columns]

# %% [markdown]
# # Building Pipeline

# %%
{column: len(X_train[column].unique()) for column in X_train.select_dtypes('object').columns}
# Out:
# {'recorddate_key': 130,
#  'birthdate_key': 5276,
#  'orighiredate_key': 4377,
#  'city_name': 40,
#  'department_name': 21,
#  'job_title': 47,
#  'gender_full': 2,
#  'BUSINESS_UNIT': 2}

# %%
X_train.select_dtypes('object')
# Out:
#         recorddate_key birthdate_key orighiredate_key        city_name  \
# 36271  12/31/2011 0:00     8/18/1979       10/30/2005       Abbotsford
# 3950   12/31/2008 0:00     4/27/1953        12/8/1991        Vancouver
# 26963  12/31/2006 0:00     9/26/1971        8/29/2001  New Westminster
# 29451  12/31/2011 0:00    10/16/1973        9/30/2002          Terrace
# 3790   12/31/2008 0:00     3/10/1953       11/13/1991          Burnaby
# ...                ...           ...              ...              ...
# 11284  12/31/2010 0:00      6/9/1959         3/2/1995        Vancouver
# 44732  12/31/2013 0:00     4/26/1988         6/1/2010          Terrace
# 38158  12/31/2012 0:00     3/13/1981        8/28/2006          Nanaimo
# 860    12/31/2007 0:00      2/6/1950        3/27/1990         Kamloops
# 15795  12/31/2011 0:00    12/14/1962         1/8/1997          Langley
#
#         department_name                job_title gender_full BUSINESS_UNIT
# 36271            Bakery                    Baker        Male        STORES
# 3950            Produce            Produce Clerk      Female        STORES
# 26963            Bakery                    Baker        Male        STORES
# 29451   Processed Foods            Shelf Stocker        Male        STORES
# 3790              Meats              Meat Cutter        Male        STORES
# ...                 ...                      ...         ...           ...
# 11284             Meats              Meat Cutter        Male        STORES
# 44732  Customer Service                  Cashier      Female        STORES
# 38158   Processed Foods            Shelf Stocker      Female        STORES
# 860     Processed Foods  Processed Foods Manager        Male        STORES
# 15795           Produce            Produce Clerk      Female        STORES
#
# [34757 rows x 8 columns]

# %%
# Transformer for date columns that extract year, month and day features
class DateTransformer:
    def fit(self,X,y):
        return self
    def transform(self,X):
        for column in X.columns:
            X[column]=pd.to_datetime(X[column])
            X[column +'_year']=X[column].apply(lambda x: x.year)
            X[column +'_month']=X[column].apply(lambda x: x.month)
            X[column +'_day']=X[column].apply(lambda x: x.day)
            X=X.drop(column,axis=1)
        return X

# %%
#classify features by type
binary_features=['gender_full','BUSINESS_UNIT']
date_features=['recorddate_key','birthdate_key','orighiredate_key']
nominal_features=['city_name','department_name','job_title']

#Construct transformers to handle each type of features
binary_transformer=Pipeline(steps=[
    ('ordinal',OrdinalEncoder(categories='auto'))
])

nominal_transformer=Pipeline(steps=[
    ('nominal',OneHotEncoder())
])
    
date_transformer=Pipeline(steps=[
    ('date',DateTransformer())
])

# %%
# Build a preprocessing transformer with ColumnTransformer
preprocessor=ColumnTransformer(transformers=[
    ('binary',binary_transformer, binary_features),
    ('nominal',nominal_transformer, nominal_features),
    ('date',date_transformer, date_features),
    
],sparse_threshold=0)

# %%
# Build the final pipeline
model=Pipeline(steps=[
    ('preprocessor',preprocessor),
    ('scaler',StandardScaler()),
    ('classifier',LogisticRegression())
])

# %% [markdown]
# # Training

# %%
model.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(sparse_threshold=0,
#                                    transformers=[('binary',
#                                                   Pipeline(steps=[('ordinal',
#                                                                    OrdinalEncoder())]),
#                                                   ['gender_full',
#                                                    'BUSINESS_UNIT']),
#                                                  ('nominal',
#                                                   Pipeline(steps=[('nominal',
#                                                                    OneHotEncoder())]),
#                                                   ['city_name',
#                                                    'department_name',
#                                                    'job_title']),
#                                                  ('date',
#                                                   Pipeline(steps=[('date',
#                                                                    <__main__.DateTransformer object at 0x142fb6bd0>)]),
#                                                   ['recorddate_key',
#                                                    'birthdate_key',
#                                                    'orighiredate_key'])])),
#                 ('scaler', StandardScaler()),
#                 ('classifier', LogisticRegression())])

# %% [markdown]
# # Results

# %%
acc=model.score(X_test,y_test)
print('Test Accuracy: {:.2f}%'.format(acc*100))
# Out:
# Test Accuracy: 100.00%
